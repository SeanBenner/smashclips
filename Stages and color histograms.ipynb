# %%
# manipulation
import numpy as np
import cv2

from sklearn.decomposition import PCA

# displaying images
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
DL = mpimg.imread('Stages/dreamland.jpg')
FD = mpimg.imread('Stages/FD.jpg')
BF = mpimg.imread('Stages/BF.jpg')
YS = mpimg.imread('Stages/YS.jpg')
PS = mpimg.imread('Stages/PS.jpg')
FoD = mpimg.imread('Stages/FoD.jpg')

# %%
grayFD = cv2.cvtColor(FD, cv2.COLOR_RGB2HSV)[:,:,0]
grayBF = cv2.cvtColor(BF, cv2.COLOR_RGB2HSV)[:,:,0]
grayYS = cv2.cvtColor(YS, cv2.COLOR_RGB2HSV)[:,:,0]
grayPS = cv2.cvtColor(PS, cv2.COLOR_RGB2HSV)[:,:,0]
grayFoD = cv2.cvtColor(FoD, cv2.COLOR_RGB2HSV)[:,:,0]
grayDL = cv2.cvtColor(DL, cv2.COLOR_RGB2HSV)[:,:,0]

# %%
grayDL.size
# Out:
# 631813

# %%
plt.plot(np.arange(179) ,(np.histogram(grayDL.ravel(), 179, [0,179])[0])/631813)

# %%
plt.hist(grayDL.ravel(), 179, [0,179])
# Out:
# (array([  1.37900000e+03,   5.92000000e+02,   6.36000000e+02,
#           3.76000000e+02,   4.21000000e+02,   5.20000000e+02,
#           1.33800000e+03,   4.56000000e+02,   1.06200000e+03,
#           1.63500000e+03,   3.32200000e+03,   5.01400000e+03,
#           4.90300000e+03,   7.64500000e+03,   8.97300000e+03,
#           8.25400000e+03,   8.70200000e+03,   1.21010000e+04,
#           3.24910000e+04,   2.37000000e+04,   1.51330000e+04,
#           7.74000000e+03,   4.31200000e+03,   2.74700000e+03,
#           1.89600000e+03,   1.66000000e+03,   1.64400000e+03,
#           1.36600000e+03,   1.37900000e+03,   1.12500000e+03,
#           1.14900000e+03,   7.81000000e+02,   6.63000000e+02,
#           7.12000000e+02,   6.34000000e+02,   7.58000000e+02,
#           4.24000000e+02,   5.13000000e+02,   4.26000000e+02,
#           4.84000000e+02,   5.22000000e+02,   4.36000000e+02,
#           5.32000000e+02,   5.76000000e+02,   4.41000000e+02,
# ...

# %%
plt.hist(grayBF.ravel(), 179, [0,179])
# Out:
# (array([  1.10042000e+05,   2.28000000e+02,   2.96000000e+02,
#           3.03000000e+02,   3.72000000e+02,   4.03000000e+02,
#           7.62000000e+02,   2.77000000e+02,   4.76000000e+02,
#           3.10000000e+02,   2.85000000e+02,   4.82000000e+02,
#           3.47000000e+02,   6.51000000e+02,   3.14000000e+02,
#           6.96000000e+02,   1.44900000e+03,   5.82000000e+02,
#           1.99000000e+02,   2.93000000e+02,   9.04000000e+02,
#           3.56000000e+02,   4.86000000e+02,   6.08000000e+02,
#           8.86000000e+02,   6.59000000e+02,   4.84000000e+02,
#           2.01000000e+02,   1.67000000e+02,   8.20000000e+01,
#           2.50000000e+03,   2.70000000e+01,   8.50000000e+01,
#           7.80000000e+01,   1.91000000e+02,   4.65000000e+02,
#           8.60000000e+02,   3.50000000e+01,   9.40000000e+01,
#           5.00000000e+01,   1.28000000e+02,   2.00000000e+01,
#           3.55000000e+02,   1.81000000e+02,   2.80000000e+01,
# ...

# %%
plt.hist(grayFD.ravel(), 256, [0,256])
# Out:
# (array([  6.72000000e+03,   3.45000000e+02,   3.98000000e+02,
#           8.31400000e+03,   3.36000000e+02,   4.74000000e+02,
#           5.08000000e+02,   3.39000000e+02,   6.14000000e+02,
#           6.22000000e+02,   7.51000000e+02,   6.10000000e+02,
#           2.51000000e+02,   2.95000000e+02,   1.36000000e+02,
#           2.09000000e+02,   1.64000000e+02,   1.17000000e+02,
#           9.40000000e+01,   1.52000000e+02,   2.62000000e+02,
#           1.61000000e+02,   1.15000000e+02,   1.01000000e+02,
#           1.53000000e+02,   1.16000000e+02,   2.12000000e+02,
#           6.10000000e+01,   7.10000000e+01,   8.90000000e+01,
#           4.15000000e+02,   3.60000000e+01,   1.12000000e+02,
#           8.20000000e+01,   1.25000000e+02,   2.50000000e+02,
#           1.42000000e+02,   1.38000000e+02,   1.61000000e+02,
#           1.29000000e+02,   2.17000000e+02,   1.03000000e+02,
#           3.09000000e+02,   3.13000000e+02,   1.30000000e+02,
# ...

# %%
plt.hist(grayPS.ravel(), 256, [0,256])
# Out:
# (array([  2.87140000e+04,   2.91000000e+02,   1.15000000e+02,
#           1.21000000e+02,   3.50000000e+01,   2.71000000e+02,
#           6.57000000e+02,   1.40000000e+01,   3.49000000e+02,
#           5.20000000e+01,   4.20000000e+01,   5.81000000e+02,
#           3.90000000e+01,   9.47000000e+02,   1.89000000e+02,
#           1.22000000e+02,   2.85000000e+02,   3.70000000e+01,
#           4.80000000e+01,   3.53000000e+02,   1.19000000e+03,
#           2.64000000e+02,   6.90000000e+01,   1.39000000e+02,
#           5.80000000e+02,   9.43000000e+02,   8.30000000e+01,
#           1.10000000e+01,   1.60000000e+01,   5.10000000e+01,
#           4.45900000e+03,   2.50000000e+01,   8.00000000e+01,
#           7.10000000e+01,   7.03000000e+02,   1.77400000e+03,
#           1.78300000e+03,   2.10000000e+01,   7.90000000e+01,
#           3.50000000e+01,   1.07000000e+02,   8.00000000e+00,
#           2.46000000e+02,   1.67000000e+02,   7.00000000e+00,
# ...

# %%
plt.hist(grayYS.ravel(), 256, [0,256])
# Out:
# (array([  2.09000000e+02,   2.22000000e+02,   4.45000000e+02,
#           1.06700000e+03,   2.24700000e+03,   3.02900000e+03,
#           3.90800000e+03,   3.19300000e+03,   2.74400000e+03,
#           2.38400000e+03,   2.11200000e+03,   2.25000000e+03,
#           2.08800000e+03,   2.71800000e+03,   2.96000000e+03,
#           3.30500000e+03,   2.75600000e+03,   2.46500000e+03,
#           2.66700000e+03,   2.91800000e+03,   4.87600000e+03,
#           6.00200000e+03,   3.92300000e+03,   2.55900000e+03,
#           1.62700000e+03,   1.22200000e+03,   1.08200000e+03,
#           8.08000000e+02,   8.16000000e+02,   6.29000000e+02,
#           6.85000000e+02,   5.39000000e+02,   7.49000000e+02,
#           1.08300000e+03,   2.42300000e+03,   2.09700000e+03,
#           8.87000000e+02,   7.43000000e+02,   6.36000000e+02,
#           6.05000000e+02,   8.67000000e+02,   1.09100000e+03,
#           4.23200000e+03,   1.95600000e+03,   1.41800000e+03,
# ...

# %%
plt.hist(grayFoD.ravel(), 256, [0,256])
# Out:
# (array([  1.47660000e+04,   6.00000000e+01,   6.30000000e+01,
#           4.90000000e+01,   7.80000000e+01,   9.30000000e+01,
#           9.30000000e+01,   3.80000000e+01,   9.50000000e+01,
#           3.90000000e+01,   4.90000000e+01,   8.00000000e+01,
#           4.00000000e+01,   1.27000000e+02,   5.40000000e+01,
#           7.40000000e+01,   8.00000000e+01,   7.10000000e+01,
#           4.10000000e+01,   6.60000000e+01,   1.39000000e+02,
#           8.90000000e+01,   6.80000000e+01,   6.10000000e+01,
#           8.80000000e+01,   5.70000000e+01,   1.13000000e+02,
#           2.90000000e+01,   5.40000000e+01,   1.06000000e+02,
#           3.22000000e+02,   1.10000000e+02,   1.22000000e+02,
#           8.60000000e+01,   1.58000000e+02,   1.47000000e+02,
#           9.20000000e+01,   6.20000000e+01,   8.40000000e+01,
#           4.40000000e+01,   6.70000000e+01,   2.90000000e+01,
#           5.20000000e+01,   5.90000000e+01,   1.10000000e+01,
# ...

# %%
np.histogram()
